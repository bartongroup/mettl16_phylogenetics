# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/cluster/ggs_lab/mtparker/.conda/envs/snakemake6/lib/python3.10/site-packages', '/cluster/ggs_lab/mtparker/papers/splice_site_phylogenetics/phylo_assoc_mapping/rules/notebook_templates']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\x1bc\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c2cm_hits/Hanseniaspora_guilliermondii.u6_hits.fasta\x94\x8c)cm_hits/Yarrowia_lipolytica.u6_hits.fasta\x94\x8c/cm_hits/Wickerhamiella_versatilis.u6_hits.fasta\x94\x8c0cm_hits/Nakaseomyces_bacillisporus.u6_hits.fasta\x94\x8c/cm_hits/Saccharomyces_pastorianus.u6_hits.fasta\x94\x8c+cm_hits/Wickerhamomyces_bovis.u6_hits.fasta\x94\x8c\'cm_hits/Candida_tropcalis.u6_hits.fasta\x94\x8c*cm_hits/Candida_metapsilosis.u6_hits.fasta\x94\x8c\'cm_hits/Yamadazyma_tenuis.u6_hits.fasta\x94\x8c&cm_hits/Pichia_terricola.u6_hits.fasta\x94\x8c*cm_hits/Hyphopichia_burtonii.u6_hits.fasta\x94\x8c/cm_hits/Metschnikowia_bicuspidata.u6_hits.fasta\x94\x8c.cm_hits/Metschnikowia_spJCM33374.u6_hits.fasta\x94\x8c,cm_hits/Zygotorulaspora_mrakii.u6_hits.fasta\x94\x8c#cm_hits/Candida_auris.u6_hits.fasta\x94\x8c/cm_hits/Schizosaccharomyces_pombe.u6_hits.fasta\x94\x8c,cm_hits/Alloascoidea_hylecoeti.u6_hits.fasta\x94\x8c,cm_hits/Tetrapisispora_blattae.u6_hits.fasta\x94\x8c+cm_hits/Kregervanrija_fluxuum.u6_hits.fasta\x94\x8c*cm_hits/Lipomyces_oligophaga.u6_hits.fasta\x94\x8c)cm_hits/Nadsonia_fulvescens.u6_hits.fasta\x94\x8c,cm_hits/Pichia_membranifaciens.u6_hits.fasta\x94\x8c&cm_hits/Candida_gorgasii.u6_hits.fasta\x94\x8c+cm_hits/Teunomyces_gatunensis.u6_hits.fasta\x94\x8c,cm_hits/Barnettozyma_salicaria.u6_hits.fasta\x94\x8c-cm_hits/Saccharomycodes_ludwigi.u6_hits.fasta\x94\x8c(cm_hits/Dipodascus_albidus.u6_hits.fasta\x94\x8c-cm_hits/Kazachstania_naganishii.u6_hits.fasta\x94\x8c*cm_hits/Millerozyma_farinosa.u6_hits.fasta\x94\x8c.cm_hits/Kregervanrija_delftensis.u6_hits.fasta\x94\x8c0cm_hits/Brettanomyces_naardenensis.u6_hits.fasta\x94\x8c)cm_hits/Suhomyces_pyralidae.u6_hits.fasta\x94\x8c1cm_hits/Saccharomycopsis_fibuligera.u6_hits.fasta\x94\x8c)cm_hits/Debaryomyces_fabryi.u6_hits.fasta\x94\x8c&cm_hits/Meyerozyma_spJA9.u6_hits.fasta\x94\x8c)cm_hits/Candida_inconspicua.u6_hits.fasta\x94\x8c3cm_hits/Diddensiella_caesifluorescens.u6_hits.fasta\x94\x8c.cm_hits/Tortispora_caseinolytica.u6_hits.fasta\x94\x8c$cm_hits/Ogataea_minuta.u6_hits.fasta\x94\x8c&cm_hits/Candida_jaroonii.u6_hits.fasta\x94\x8c/cm_hits/Metschnikowia_pulcherrima.u6_hits.fasta\x94\x8c)cm_hits/Millerozyma_acaciae.u6_hits.fasta\x94\x8c)cm_hits/Tortispora_starmeri.u6_hits.fasta\x94\x8c,cm_hits/Hanseniaspora_opuntiae.u6_hits.fasta\x94\x8c(cm_hits/Ascoidea_rubescens.u6_hits.fasta\x94\x8c*cm_hits/Candida_dubliniensis.u6_hits.fasta\x94\x8c-cm_hits/Torulaspora_delbrueckii.u6_hits.fasta\x94\x8c-cm_hits/Wickerhamia_fluorescens.u6_hits.fasta\x94\x8c+cm_hits/Cyberlindnera_jadinii.u6_hits.fasta\x94\x8c,cm_hits/Caenorhabditis_elegans.u6_hits.fasta\x94\x8c*cm_hits/Phaffomyces_opuntiae.u6_hits.fasta\x94\x8c(cm_hits/Ogataea_polymorpha.u6_hits.fasta\x94\x8c)cm_hits/Brettanomyces_nanus.u6_hits.fasta\x94\x8c/cm_hits/Wickerhamiella_sorbophila.u6_hits.fasta\x94\x8c/cm_hits/Lodderomyces_elongesporus.u6_hits.fasta\x94\x8c%cm_hits/Ogataea_zsoltii.u6_hits.fasta\x94\x8c+cm_hits/Candida_orthopsilosis.u6_hits.fasta\x94\x8c(cm_hits/Diutina_catenulata.u6_hits.fasta\x94\x8c0cm_hits/Magnusiomyces_tetraspermus.u6_hits.fasta\x94\x8c.cm_hits/Wickerhamomyces_anomalus.u6_hits.fasta\x94\x8c.cm_hits/Wickerhamomyces_ciferrii.u6_hits.fasta\x94\x8c)cm_hits/Starmerella_apicola.u6_hits.fasta\x94\x8c\'cm_hits/Pichia_manshurica.u6_hits.fasta\x94\x8c\'cm_hits/Candida_subhashii.u6_hits.fasta\x94\x8c-cm_hits/Saccharomyces_eubayanus.u6_hits.fasta\x94\x8c(cm_hits/Kodamaea_laetipori.u6_hits.fasta\x94\x8c*cm_hits/Candida_jiufengensis.u6_hits.fasta\x94\x8c.cm_hits/Zygosaccharomyces_rouxii.u6_hits.fasta\x94\x8c(cm_hits/Saprochaete_ingens.u6_hits.fasta\x94\x8c.cm_hits/Spathaspora_passalidarum.u6_hits.fasta\x94\x8c(cm_hits/Yamadazyma_scolyti.u6_hits.fasta\x94\x8c+cm_hits/Clavispora_lusitaniae.u6_hits.fasta\x94\x8c(cm_hits/Lipomyces_starkeyi.u6_hits.fasta\x94\x8c\'cm_hits/Zygoascus_meyerae.u6_hits.fasta\x94\x8c(cm_hits/Pichia_norvegensis.u6_hits.fasta\x94\x8c)cm_hits/Ogataea_ramenticola.u6_hits.fasta\x94\x8c(cm_hits/Lachancea_meyersii.u6_hits.fasta\x94\x8c*cm_hits/Wickerhamomyces_alni.u6_hits.fasta\x94\x8c
omyces_mucosus\x94\x8c\x18Wickerhamomyces_ciferrii\x94\x8c\x18Wickerhamomyces_anomalus\x94\x8c\x14Wickerhamomyces_alni\x94\x8c\x15Wickerhamomyces_bovis\x94\x8c\x15Cyberlindnera_jadinii\x94\x8c\x16Cyberlindnera_fabianii\x94\x8c\x14Cyberlindnera_mrakii\x94\x8c\x18Barnettozyma_californica\x94\x8c\x16Barnettozyma_salicaria\x94\x8c\x16Barnettozyma_pratensis\x94\x8c\x0fCandida_montana\x94\x8c\x14Phaffomyces_opuntiae\x94euu\x8c\x04rule\x94\x8c\x0bu6_analysis\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cg/cluster/ggs_lab/mtparker/papers/splice_site_phylogenetics/phylo_assoc_mapping/rules/notebook_templates\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/cluster/ggs_lab/mtparker/papers/splice_site_phylogenetics/phylo_assoc_mapping/pipeline/ascomycota');
######## snakemake preamble end #########

# %%
import os
import re
from glob import glob
import itertools as it
import tempfile
import warnings
import subprocess as sp
from copy import copy

import numpy as np
import pandas as pd
from scipy import stats

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap, Normalize, to_hex
from matplotlib.cm import ScalarMappable
import seaborn as sns

import ete3
os.environ['QT_QPA_PLATFORM']='offscreen'

## Default plotting params
# %matplotlib inline
sns.set(font='Arial')
plt.rcParams['svg.fonttype'] = 'none'
style = sns.axes_style('white')
style.update(sns.axes_style('ticks'))
style['xtick.major.size'] = 2
style['ytick.major.size'] = 2
sns.set(font_scale=1.2, style=style)
pal = sns.color_palette(['#0072b2', '#d55e00', '#009e73', '#f0e442', '#cc79a7', '#56b4e9', '#e69f00'])
cmap = ListedColormap(pal.as_hex())
sns.set_palette(pal)
sns.palplot(pal)
plt.show()

# %%
def _parse_fasta(buffer):
    seqs = {}
    try:
        seq_id = next(buffer).strip().split(' ')[0][1:]
    except StopIteration:
        # file is empty
        return seqs
    seq = []
    for line in buffer:
        if not line.startswith('>'):
            seq.append(line.strip())
        else:
            seqs[seq_id] = ''.join(seq)
            seq_id = line.strip().split(' ')[0][1:]
            seq = []
    else:
        seqs[seq_id] = ''.join(seq)
    return seqs


def read_fasta(fasta_fn):
    with open(fasta_fn) as f:
        seqs = _parse_fasta(f)
    return seqs


def read_cm_hit_fastas(fasta_fns):
    res = []
    for fn in fasta_fns:
        for seq_id, seq in read_fasta(fn).items():
            species, score, contig, start, end, strand = re.search(
                '^(\w+)\|([\de\-\.]+)::([^:]+):(\d+)-(\d+)\(([+-])\)$',
                seq_id
            ).groups()
            score = float(score)
            start, end = int(start), int(end)
            res.append([species, contig, start, end, strand, score, seq.upper()])
    return pd.DataFrame(res, columns=['species', 'contig', 'start', 'end', 'strand', 'e_val', 'seq'])


def sanitise_rna_seqs(seqs):
    cleaned = {
        seq_id: re.sub('[^ACGUT]', 'N', seq)
        for seq_id, seq in seqs.items()
    }
    return cleaned


def cm_consensus(cm_fn):
    proc = sp.run(
        f'cmemit -c {cm_fn}',
        shell=True,
        check=True,
        stderr=sp.DEVNULL,
        stdout=sp.PIPE
    )
    seq = _parse_fasta(iter(proc.stdout.decode().split('\n')))
    assert len(seq) == 1
    return list(seq.values())[0].upper()


def _cmalign(seqs, cm_fn):
    tmp_fh, tmp_fn = tempfile.mkstemp()
    with open(tmp_fn, 'w') as tmp:
        for seq_id, seq in sanitise_rna_seqs(seqs).items():
            tmp.write(f">{seq_id}\n{seq}\n")
    proc = sp.run(
        f'cmalign --outformat afa --matchonly {cm_fn} {tmp_fn}',
        shell=True,
        check=True,
        stdout=sp.PIPE,
        stderr=sp.DEVNULL
    )
    os.close(tmp_fh)
    os.remove(tmp_fn)
    return _parse_fasta(iter(proc.stdout.decode().split('\n')))


def cm_align(seqs, cm_fn):
    cm_cons = cm_consensus(cm_fn)
    seqs = copy(seqs)
    seqs['cm_consensus'] = cm_cons
    aln = _cmalign(seqs, cm_fn)
    alned_cons = seqs.pop('cm_consensus')
    return alned_cons, aln

# %%
u6_aln_res = read_cm_hit_fastas(snakemake.input.u6_aln)
u6_aln_best_hit = u6_aln_res.sort_values('e_val').drop_duplicates(subset='species', keep='first')
known_clades = {
    sp: clade for clade, species_list in snakemake.config['known_clades'].items() for sp in species_list
}
u6_aln_best_hit['clade'] = u6_aln_best_hit.species.map(known_clades)

# %%
clade_colours = {
    'Outgroups': '#7c7c7c',
    'Lipomycetaceae': '#f1c232',
    'Trigonopsidaceae': '#bf9000',
    'Dipodascaceae': '#ff0000',
    'Alloascoideaceae': '#c27ba0',
    'CUG-Ser2': '#d55e00',
    'Phaffomycetaceae': '#ee9956',
    'CUG-Ser1': '#0072b2',
    'CUG-Ala': '#56b4e9',
    'Pichiaceae': '#674ea7',
    'Saccharomycodaceae': '#00f3b1',
    'Saccharomycetaceae': '#009e73',
}

data = []
zorder = 0
fig, ax = plt.subplots(figsize=(7, 5))
for clade, group in u6_aln_best_hit.groupby('clade'):
    data += (-np.log10(group.e_val)).values.tolist()
    ax.hist(data, range=(0, 25), bins=25, zorder=zorder, color=clade_colours[clade])
    zorder -= 1
ax.set_xlabel('-log10 E value of best hit')
ax.set_ylabel('Species')
plt.show()

# %%
aln_cons, aln = cm_align(
    u6_aln_best_hit.set_index('species').seq.to_dict(), 
    '../../annotations/cms/u6.cm'
)
u6_aln_best_hit['aln'] = u6_aln_best_hit.species.map(aln)
u6_aln_best_hit.head()

# %%
with open(os.path.join(os.environ['TMPDIR'], 'u6.fa'), 'w') as f:
    for sp, seq in u6_aln_best_hit.set_index('species').seq.to_dict().items():
        f.write(f'>{sp}\n{seq}\n')

# %%
# %%bash
#
# cmalign \
#   --mapali '../../annotations/cms/u6_seed_aln.sto' \
#   --mapstr \
#   '../../annotations/cms/u6.cm' \
#   ${TMPDIR}/u6.fa |
# grep -v "^SEED_" > ${TMPDIR}/u6_aln.sto
# ../../scripts/rscape_v2.0.0.q/bin/R-scape --outdir $TMPDIR --outname u6_aln ${TMPDIR}/u6_aln.sto

# %%
# !mv {os.path.join(os.environ['TMPDIR'], 'u6_aln.R2R.sto.svg')} {snakemake.output.svg}
